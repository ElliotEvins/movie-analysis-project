# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
sns.set(style="ticks")

# %%
studio_chungus = pd.read_csv('../unzipped-data/bom.movie_gross.csv')

# %%
#studio_chungus['foreign_gross'] = studio_chungus['foreign_gross'].str.replace(".", "").str.replace(",","")
#studio_chungus['foreign_gross'] = studio_chungus['foreign_gross'].astype('float')
studio_chungus['total_gross'] = studio_chungus['foreign_gross'] + studio_chungus['domestic_gross']

# %%
studio_chungus.dropna(subset=['total_gross'], inplace=True)
studio_chungus.head()
# Out:
#                                          title studio  domestic_gross  \
# 0                                  Toy Story 3     BV     415000000.0
# 1                   Alice in Wonderland (2010)     BV     334200000.0
# 2  Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                    Inception     WB     292600000.0
# 4                          Shrek Forever After   P/DW     238700000.0
#
#    foreign_gross  year   total_gross
# 0    652000000.0  2010  1.067000e+09
# 1    691300000.0  2010  1.025500e+09
# 2    664300000.0  2010  9.603000e+08
# 3    535700000.0  2010  8.283000e+08
# 4    513900000.0  2010  7.526000e+08

# %%
studio_chungus.sort_values(by = 'domestic_gross', ascending = False)
# Out:
#                              title  studio  domestic_gross  foreign_gross  \
# 1872  Star Wars: The Force Awakens      BV     936700000.0        11316.0
# 3080                 Black Panther      BV     700100000.0    646900000.0
# 3079        Avengers: Infinity War      BV     678800000.0        13695.0
# 1873                Jurassic World    Uni.     652300000.0        10194.0
# 727          Marvel's The Avengers      BV     623400000.0    895500000.0
# ...                            ...     ...             ...            ...
# 1738                       Jackpot      DR           800.0      1100000.0
# 292               Perrier's Bounty     IFC           800.0       167000.0
# 2920     Amityville: The Awakening  W/Dim.           700.0      7700000.0
# 642                 Illegal (2011)      FM           700.0       289000.0
# 1018                 Apartment 143   Magn.           400.0       426000.0
#
#       year   total_gross
# 1872  2015  9.367113e+08
# 3080  2018  1.347000e+09
# ...

# %%
sns.barplot(x='total_gross', y = 'studio', data = studio_chungus)
plt.show()
